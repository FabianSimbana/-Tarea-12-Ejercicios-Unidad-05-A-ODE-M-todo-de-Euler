# %% [markdown]
# ## 1.Use el método de Euler para aproximar las soluciones para cada uno de los siguientes problemas de valor inicial.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definición de la función derivada
def f(t, y):
    return t * np.exp(3*t) - 2*y

# Parámetros iniciales
h = 0.5
t0 = 0
y0 = 0
tf = 1
n_steps = int((tf - t0) / h)

# Inicialización de listas para almacenar los resultados
t_values = [t0]
y_values = [y0]

# Método de Euler
for i in range(n_steps):
    t_n = t_values[-1]
    y_n = y_values[-1]
    
    y_next = y_n + h * f(t_n, y_n)
    t_next = t_n + h
    
    t_values.append(t_next)
    y_values.append(y_next)

print(t_values, y_values)

# Graficar los resultados
plt.plot(t_values, y_values, 'o-', label='Solución Euler')
plt.xlabel('t')
plt.ylabel('y(t)')
plt.title('Ejercicio 1.a')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# [0, 0.5, 1.0] [0, np.float64(0.0), np.float64(1.1204222675845161)]

# %%
# Definición de la función derivada
def f(t, y):
    return 1 + (t - y)**2

# Parámetros iniciales
h = 0.5
t0 = 2
y0 = 1
tf = 3
n_steps = int((tf - t0) / h)

# Inicialización de listas para almacenar los resultados
t_values = [t0]
y_values = [y0]

# Método de Euler
for i in range(n_steps):
    t_n = t_values[-1]
    y_n = y_values[-1]
    
    y_next = y_n + h * f(t_n, y_n)
    t_next = t_n + h
    
    t_values.append(t_next)
    y_values.append(y_next)
print(t_values, y_values)
# Graficar los resultados
plt.plot(t_values, y_values, 'o-', label='Solución Euler')
plt.xlabel('t')
plt.ylabel('y(t)')
plt.title('Ejercicio 1.b')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# [2, 2.5, 3.0] [1, 2.0, 2.625]

# %%
# Definición de la función derivada
def f(t, y):
    return 1 + y/t

# Parámetros iniciales
h = 0.25
t0 = 1
y0 = 2
tf = 2
n_steps = int((tf - t0) / h)

# Inicialización de listas para almacenar los resultados
t_values = [t0]
y_values = [y0]

# Método de Euler
for i in range(n_steps):
    t_n = t_values[-1]
    y_n = y_values[-1]
    
    y_next = y_n + h * f(t_n, y_n)
    t_next = t_n + h
    
    t_values.append(t_next)
    y_values.append(y_next)
print(t_values, y_values)
# Graficar los resultados
plt.plot(t_values, y_values, 'o-', label='Solución Euler')
plt.xlabel('t')
plt.ylabel('y(t)')
plt.title('Ejercicio 1.c')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# [1, 1.25, 1.5, 1.75, 2.0] [2, 2.75, 3.55, 4.391666666666667, 5.269047619047619]

# %%
# Definición de la función derivada
def f(t, y):
    return np.cos(2*t) + np.sin(3*t)

# Parámetros iniciales
h = 0.25
t0 = 0
y0 = 1
tf = 1
n_steps = int((tf - t0) / h)

# Inicialización de listas para almacenar los resultados
t_values = [t0]
y_values = [y0]

# Método de Euler
for i in range(n_steps):
    t_n = t_values[-1]
    y_n = y_values[-1]
    
    y_next = y_n + h * f(t_n, y_n)
    t_next = t_n + h
    
    t_values.append(t_next)
    y_values.append(y_next)
print(t_values, y_values)
# Graficar los resultados
plt.plot(t_values, y_values, 'o-', label='Solución Euler')
plt.xlabel('t')
plt.ylabel('y(t)')
plt.title('Ejercicio 1.c')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# [0, 0.25, 0.5, 0.75, 1.0] [1, np.float64(1.25), np.float64(1.6398053304784268), np.float64(2.0242546535964756), np.float64(2.2364572532353817)]

# %% [markdown]
# ## 2. Las soluciones reales para los problemas de valor inicial en el ejercicio 1 se proporcionan aquí. Compare el error real en cada paso

# %%
# Parámetros
h = 0.5
t0 = 0
y0 = 0
t_end = 1

# Método de Euler
n_steps = int((t_end - t0) / h)
t_values = np.zeros(n_steps + 1)
y_values = np.zeros(n_steps + 1)

t_values[0] = t0
y_values[0] = y0

for i in range(1, n_steps + 1):
    y_values[i] = y_values[i-1] + h * (t_values[i-1] * np.exp(3 * t_values[i-1]) - 2 * y_values[i-1])
    t_values[i] = t_values[i-1] + h

# Solución exacta
t_exact = np.linspace(t0, t_end, 100)
y_exact = (1/5)*t_exact*np.exp(3*t_exact) - (1/25)*np.exp(3*t_exact) + (1/25)*np.exp(-2*t_exact)

# Gráfico de resultados
plt.plot(t_values, y_values, 'ro-', label='Euler')
plt.plot(t_exact, y_exact, 'b-', label='Solución Exacta')
plt.xlabel('t')
plt.ylabel('y(t)')
plt.title('Método de Euler vs. Solución Exacta')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Parámetros
h = 0.5
t0 = 2
y0 = 1
t_end = 3

# Método de Euler
n_steps = int((t_end - t0) / h)
t_values = np.zeros(n_steps + 1)
y_values = np.zeros(n_steps + 1)

t_values[0] = t0
y_values[0] = y0

for i in range(1, n_steps + 1):
    y_values[i] = y_values[i-1] + h * (1 + (t_values[i-1] - y_values[i-1])**2)
    t_values[i] = t_values[i-1] + h

# Solución exacta
t_exact = np.linspace(t0, t_end, 100)
y_exact = t_exact + 1 / (1 - t_exact)

# Gráfico de resultados
plt.plot(t_values, y_values, 'ro-', label='Euler')
plt.plot(t_exact, y_exact, 'b-', label='Solución Exacta')
plt.xlabel('t')
plt.ylabel('y(t)')
plt.title('Método de Euler vs. Solución Exacta')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Parámetros
h = 0.25
t0 = 1
y0 = 2
t_end = 2

# Método de Euler
n_steps = int((t_end - t0) / h)
t_values = np.zeros(n_steps + 1)
y_values = np.zeros(n_steps + 1)

t_values[0] = t0
y_values[0] = y0

for i in range(1, n_steps + 1):
    y_values[i] = y_values[i-1] + h * (1 + y_values[i-1] / t_values[i-1])
    t_values[i] = t_values[i-1] + h

# Solución exacta
t_exact = np.linspace(t0, t_end, 100)
y_exact = t_exact * np.log(t_exact) + 2 * t_exact

# Gráfico de resultados
plt.plot(t_values, y_values, 'ro-', label='Euler')
plt.plot(t_exact, y_exact, 'b-', label='Solución Exacta')
plt.xlabel('t')
plt.ylabel('y(t)')
plt.title('Método de Euler vs. Solución Exacta')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Parámetros
h = 0.25
t0 = 0
y0 = 1
t_end = 1

# Método de Euler
n_steps = int((t_end - t0) / h)
t_values = np.zeros(n_steps + 1)
y_values = np.zeros(n_steps + 1)

t_values[0] = t0
y_values[0] = y0

for i in range(1, n_steps + 1):
    y_values[i] = y_values[i-1] + h * (np.cos(2 * t_values[i-1]) + np.sin(3 * t_values[i-1]))
    t_values[i] = t_values[i-1] + h

# Solución exacta
t_exact = np.linspace(t0, t_end, 100)
y_exact = 0.5 * np.sin(2 * t_exact) - (1/3) * np.cos(3 * t_exact) + 4/3

# Gráfico de resultados
plt.plot(t_values, y_values, 'ro-', label='Euler')
plt.plot(t_exact, y_exact, 'b-', label='Solución Exacta')
plt.xlabel('t')
plt.ylabel('y(t)')
plt.title('Método de Euler vs. Solución Exacta')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 3.	Utilice el método de Euler para aproximar las soluciones para cada uno de los siguientes problemas de valor inicial.

# %%
# Definición de la función derivada
def f(t, y):
    return (y/t) - (y/t)**2

# Parámetros iniciales
h = 0.1
t0 = 1
y0 = 1
tf = 2
n_steps = int((tf - t0) / h)

# Inicialización de listas para almacenar los resultados
t_values = [t0]
y_values = [y0]

# Método de Euler Implícito
for i in range(n_steps):
    t_n = t_values[-1]
    y_n = y_values[-1]
    
    # Estimación inicial usando Euler explícito
    y_guess = y_n + h * f(t_n, y_n)
    
    # Corrección iterativa para aproximar el valor de y_n+1
    y_next = y_guess  # Iniciar con la estimación de Euler explícito
    for _ in range(10):  # Número de iteraciones para convergencia
        y_next = y_n + h * f(t_n + h, y_next)
    
    t_next = t_n + h
    
    t_values.append(t_next)
    y_values.append(y_next)

# Graficar los resultados
plt.plot(t_values, y_values, 'o-', label='Solución Euler Implícito')
plt.xlabel('t')
plt.ylabel('y(t)')
plt.title('Solución usando Método de Euler Implícito')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Definición de la función derivada
def f(t, y):
    return 1 + (y/t) + (y/t)**2

# Parámetros iniciales
h = 0.2
t0 = 1
y0 = 0
tf = 3
n_steps = int((tf - t0) / h)

# Inicialización de listas para almacenar los resultados
t_values = [t0]
y_values = [y0]

# Método de Euler Implícito
for i in range(n_steps):
    t_n = t_values[-1]
    y_n = y_values[-1]
    
    # Estimación inicial usando Euler explícito
    y_guess = y_n + h * f(t_n, y_n)
    
    # Corrección iterativa para aproximar el valor de y_n+1
    y_next = y_guess  # Iniciar con la estimación de Euler explícito
    for _ in range(10):  # Número de iteraciones para convergencia
        y_next = y_n + h * f(t_n + h, y_next)
    
    t_next = t_n + h
    
    t_values.append(t_next)
    y_values.append(y_next)

# Graficar los resultados
plt.plot(t_values, y_values, 'o-', label='Solución Euler Implícito')
plt.xlabel('t')
plt.ylabel('y(t)')
plt.title('Solución usando Método de Euler Implícito')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Definición de la función derivada
def f(t, y):
    return -(y + 1)*(y + 3)

# Parámetros iniciales
h = 0.2
t0 = 0
y0 = -2
tf = 2
n_steps = int((tf - t0) / h)

# Inicialización de listas para almacenar los resultados
t_values = [t0]
y_values = [y0]

# Método de Euler Implícito
for i in range(n_steps):
    t_n = t_values[-1]
    y_n = y_values[-1]
    
    # Estimación inicial usando Euler explícito
    y_guess = y_n + h * f(t_n, y_n)
    
    # Corrección iterativa para aproximar el valor de y_n+1
    y_next = y_guess  # Iniciar con la estimación de Euler explícito
    for _ in range(10):  # Número de iteraciones para convergencia
        y_next = y_n + h * f(t_n + h, y_next)
    
    t_next = t_n + h
    
    t_values.append(t_next)
    y_values.append(y_next)

# Graficar los resultados
plt.plot(t_values, y_values, 'o-', label='Solución Euler Implícito')
plt.xlabel('t')
plt.ylabel('y(t)')
plt.title('Solución usando Método de Euler Implícito')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Definición de la función derivada
def f(t, y):
    return -5*y + 5*t**2 + 2*t

# Parámetros iniciales
h = 0.1
t0 = 0
y0 = 1/3
tf = 1
n_steps = int((tf - t0) / h)

# Inicialización de listas para almacenar los resultados
t_values = [t0]
y_values = [y0]

# Método de Euler Implícito
for i in range(n_steps):
    t_n = t_values[-1]
    y_n = y_values[-1]
    
    # Estimación inicial usando Euler explícito
    y_guess = y_n + h * f(t_n, y_n)
    
    # Corrección iterativa para aproximar el valor de y_n+1
    y_next = y_guess  # Iniciar con la estimación de Euler explícito
    for _ in range(10):  # Número de iteraciones para convergencia
        y_next = y_n + h * f(t_n + h, y_next)
    
    t_next = t_n + h
    
    t_values.append(t_next)
    y_values.append(y_next)

# Graficar los resultados
plt.plot(t_values, y_values, 'o-', label='Solución Euler Implícito')
plt.xlabel('t')
plt.ylabel('y(t)')
plt.title('Solución usando Método de Euler Implícito')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ## 4.	Aquí se dan las soluciones reales para los problemas de valor inicial en el ejercicio 3. Calcule el error real en las aproximaciones del ejercicio

# %%
# Definición de la función derivada
def f(t, y):
    return (y/t) - (y/t)**2

# Parámetros iniciales
h = 0.1
t0 = 1
y0 = 1
tf = 2
n_steps = int((tf - t0) / h)

# Inicialización de listas para almacenar los resultados
t_values = [t0]
y_values = [y0]

# Método de Euler Implícito
for i in range(n_steps):
    t_n = t_values[-1]
    y_n = y_values[-1]
    
    # Estimación inicial usando Euler explícito
    y_guess = y_n + h * f(t_n, y_n)
    
    # Corrección iterativa para aproximar el valor de y_n+1
    y_next = y_guess  # Iniciar con la estimación de Euler explícito
    for _ in range(10):  # Número de iteraciones para convergencia
        y_next = y_n + h * f(t_n + h, y_next)
    
    t_next = t_n + h
    
    t_values.append(t_next)
    y_values.append(y_next)


def solucion_real(t):
    return t / (1 + np.log(t))

t_values2 = np.linspace(t0, tf, n_steps)
y_values2 = np.zeros(n_steps)

# Calculamos la solución real en los puntos t_values
sol_real = solucion_real(t_values2)

# Graficar los resultados
plt.plot(t_values, y_values, 'o-', label='Solución Euler ')
plt.plot(t_values2, sol_real, 'r-', label="Solución real")
plt.xlabel('t')
plt.ylabel('y(t)')
plt.title('Solución usando Método de Euler Implícito')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Definición de la función derivada
def f(t, y):
    return 1 + (y/t) + (y/t)**2

# Parámetros iniciales
h = 0.2
t0 = 1
y0 = 0
tf = 3
n_steps = int((tf - t0) / h)

# Inicialización de listas para almacenar los resultados
t_values = [t0]
y_values = [y0]

# Método de Euler Implícito
for i in range(n_steps):
    t_n = t_values[-1]
    y_n = y_values[-1]
    
    # Estimación inicial usando Euler explícito
    y_guess = y_n + h * f(t_n, y_n)
    
    # Corrección iterativa para aproximar el valor de y_n+1
    y_next = y_guess  # Iniciar con la estimación de Euler explícito
    for _ in range(10):  # Número de iteraciones para convergencia
        y_next = y_n + h * f(t_n + h, y_next)
    
    t_next = t_n + h
    
    t_values.append(t_next)
    y_values.append(y_next)

def solucion_real(t):
    return t * np.tan(np.log(t))

t_values2 = np.linspace(t0, tf, n_steps)
y_values2 = np.zeros(n_steps)

# Calculamos la solución real en los puntos t_values
sol_real = solucion_real(t_values2)

# Graficar los resultados
plt.plot(t_values, y_values, 'o-', label='Solución Euler Implícito')
plt.plot(t_values2, sol_real, 'r-', label="Solución real")
plt.xlabel('t')
plt.ylabel('y(t)')
plt.title('Solución usando Método de Euler Implícito')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Definición de la función derivada
def f(t, y):
    return -(y + 1)*(y + 3)

# Parámetros iniciales
h = 0.2
t0 = 0
y0 = -2
tf = 2
n_steps = int((tf - t0) / h)

# Inicialización de listas para almacenar los resultados
t_values = [t0]
y_values = [y0]

# Método de Euler Implícito
for i in range(n_steps):
    t_n = t_values[-1]
    y_n = y_values[-1]
    
    # Estimación inicial usando Euler explícito
    y_guess = y_n + h * f(t_n, y_n)
    
    # Corrección iterativa para aproximar el valor de y_n+1
    y_next = y_guess  # Iniciar con la estimación de Euler explícito
    for _ in range(10):  # Número de iteraciones para convergencia
        y_next = y_n + h * f(t_n + h, y_next)
    
    t_next = t_n + h
    
    t_values.append(t_next)
    y_values.append(y_next)

def solucion_real(t):
    return -3 + 2 / (1 + np.exp(-2*t))

t_values2 = np.linspace(t0, tf, n_steps)
y_values2 = np.zeros(n_steps)

# Calculamos la solución real en los puntos t_values
sol_real = solucion_real(t_values2)

    


# Graficar los resultados
plt.plot(t_values, y_values, 'o-', label='Solución Euler Implícito')
plt.plot(t_values2, sol_real, 'r-', label="Solución real")
plt.xlabel('t')
plt.ylabel('y(t)')
plt.title('Solución usando Método de Euler Implícito')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Definición de la función derivada
def f(t, y):
    return -5*y + 5*t**2 + 2*t

# Parámetros iniciales
h = 0.1
t0 = 0
y0 = 1/3
tf = 1
n_steps = int((tf - t0) / h)

# Inicialización de listas para almacenar los resultados
t_values = [t0]
y_values = [y0]

# Método de Euler Implícito
for i in range(n_steps):
    t_n = t_values[-1]
    y_n = y_values[-1]
    
    # Estimación inicial usando Euler explícito
    y_guess = y_n + h * f(t_n, y_n)
    
    # Corrección iterativa para aproximar el valor de y_n+1
    y_next = y_guess  # Iniciar con la estimación de Euler explícito
    for _ in range(10):  # Número de iteraciones para convergencia
        y_next = y_n + h * f(t_n + h, y_next)
    
    t_next = t_n + h
    
    t_values.append(t_next)
    y_values.append(y_next)

def solucion_real(t):
    return t**2 + (1/3)*np.exp(-5*t)

t_values2 = np.linspace(t0, tf, n_steps)
y_values2 = np.zeros(n_steps)

# Calculamos la solución real en los puntos t_values
sol_real = solucion_real(t_values2)

# Graficar los resultados
plt.plot(t_values, y_values, 'o-', label='Solución Euler Implícito')
plt.plot(t_values2, sol_real, 'r-', label="Solución real")
plt.xlabel('t')
plt.ylabel('y(t)')
plt.title('Solución usando Método de Euler Implícito')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ## 5. Utilice los resultados del ejercicio 3 y la interpolación lineal para aproximar los siguientes valores de 𝑦(𝑡). Compare las aproximaciones asignadas para los valores reales obtenidos mediante las funciones determinadas en el ejercicio 4.

# %%
from typing import Callable

def ODE_euler(
    *,
    a: float,
    b: float,
    f: Callable[[float, float], float],
    y_t0: float,
    N: int,
) -> tuple[list[float], list[float], float]:
    
    h = (b - a) / N #Se debe ajustar N para que h = 0.1
    t = a
    ts = [t]
    ys = [y_t0]

    for _ in range(N):
        y = ys[-1]
        y += h * f(t, y)
        ys.append(y)
        t += h
        ts.append(t)
    return ys, ts, h

f = lambda t, y: -5*y + 5*t**2 + 2*t
y_t0 = 1/3

a = 0
b = 1

ys,ts, h = ODE_euler(a=a, b=b, y_t0=y_t0, f=f, N=10)
print(ys)


# Parámetros del problema
h=0.1
n = int((b - a) / h) + 1 #numero de pasos

def solucion_real(t):
    return t**2 + (1/3) * np.exp(-5*t)
t_values = np.linspace(a, b, n)
y_values = np.zeros(n)

# Calculamos la solución real en los puntos t_values
sol_real = solucion_real(t_values)

#Calcular interpolación

def linear_interpolation(x0: float, y0: float, x1: float, y1: float, x: float) -> float:
    return y0 + (y1 - y0) * (x - x0) / (x1 - x0)

def interpolate_and_compare(ts, ys, exact_solution, points):
    results = []
    for t in points:
        # Encontrar los puntos entre los que se va a interpolar
        for i in range(len(ts) - 1):
            if ts[i] <= t <= ts[i+1]:
                approx = linear_interpolation(ts[i], ys[i], ts[i+1], ys[i+1], t)
                exact = exact_solution(t)
                error = abs(approx - exact)
                results.append((t, approx, exact, error))
                break
    return results
# Puntos a interpolar
points_a = [0.25, 0.93]

# Interpolación y comparación
results_a = interpolate_and_compare(ts, ys, solucion_real, points_a)

# Mostrar resultados
for t, approx, exact, error in results_a:
    print(f"t = {t:.2f}, Error: {error:.5f}")


#Graficar
for t, approx, exact, _ in results_a:
    plt.plot([t, t], [exact, approx], 'g--')  # Línea entre la solución real y la aproximación

# Mostrar los puntos exactos y aproximados
exact_ts = [t for t, _, exact, _ in results_a]
exact_ys = [exact for _, _, exact, _ in results_a]
approx_ys = [approx for _, approx, _, _ in results_a]

plt.plot(exact_ts, exact_ys, 'ro', label="Solución exacta en puntos interpolados")
plt.plot(exact_ts, approx_ys, 'bo', label="Aproximación en puntos interpolados")


plt.plot(t_values, sol_real, 'r-', label="Solución real")

plt.plot(ts, ys, marker="o", linestyle=":", label=r"$\hat{y}$")
plt.xlabel("Time")
plt.ylabel("Y")
plt.title("Solución usando Método de Euler")
plt.legend()
plt.show()
# Out:
# [0.3333333333333333, 0.16666666666666666, 0.10833333333333334, 0.11416666666666667, 0.16208333333333336, 0.2410416666666667, 0.34552083333333333, 0.4727604166666667, 0.6213802083333333, 0.7906901041666666, 0.9803450520833332]
# t = 0.25, Error: 0.04675
# t = 0.93, Error: 0.02050

# %%
from typing import Callable

def ODE_euler(
    *,
    a: float,
    b: float,
    f: Callable[[float, float], float],
    y_t0: float,
    N: int,
) -> tuple[list[float], list[float], float]:
    
    h = (b - a) / N #Se debe ajustar N para que h = 0.1
    t = a
    ts = [t]
    ys = [y_t0]

    for _ in range(N):
        y = ys[-1]
        y += h * f(t, y)
        ys.append(y)
        t += h
        ts.append(t)
    return ys, ts, h

f = lambda t, y: 1 + y/t + (y/t)**2
y_t0 = 0

a = 1
b = 3

ys,ts, h = ODE_euler(a=a, b=b, y_t0=y_t0, f=f, N=10)
print(ys)

# Parámetros del problema
h=0.2
n = int((b - a) / h) + 1 #numero de pasos

def solucion_real(t):
    return t * np.tan(np.log(t))
t_values = np.linspace(a, b, n)
y_values = np.zeros(n)

# Calculamos la solución real en los puntos t_values
sol_real = solucion_real(t_values)

#Calcular interpolación

def linear_interpolation(x0: float, y0: float, x1: float, y1: float, x: float) -> float:
    return y0 + (y1 - y0) * (x - x0) / (x1 - x0)

def interpolate_and_compare(ts, ys, exact_solution, points):
    results = []
    for t in points:
        # Encontrar los puntos entre los que se va a interpolar
        for i in range(len(ts) - 1):
            if ts[i] <= t <= ts[i+1]:
                approx = linear_interpolation(ts[i], ys[i], ts[i+1], ys[i+1], t)
                exact = exact_solution(t)
                error = abs(approx - exact)
                results.append((t, approx, exact, error))
                break
    return results
# Puntos a interpolar
points_a = [1.25, 1.93]

# Interpolación y comparación
results_a = interpolate_and_compare(ts, ys, solucion_real, points_a)

# Mostrar resultados
for t, approx, exact, error in results_a:
    print(f"t = {t:.2f}, Error: {error:.5f}")


#Graficar
for t, approx, exact, _ in results_a:
    plt.plot([t, t], [exact, approx], 'g--')  # Línea entre la solución real y la aproximación

# Mostrar los puntos exactos y aproximados
exact_ts = [t for t, _, exact, _ in results_a]
exact_ys = [exact for _, _, exact, _ in results_a]
approx_ys = [approx for _, approx, _, _ in results_a]

plt.plot(exact_ts, exact_ys, 'ro', label="Solución exacta en puntos interpolados")
plt.plot(exact_ts, approx_ys, 'bo', label="Aproximación en puntos interpolados")


plt.plot(t_values, sol_real, 'r-', label="Solución real")

plt.plot(ts, ys, marker="o", linestyle=":", label=r"$\hat{y}$")
plt.xlabel("Time")
plt.ylabel("Y")
plt.title("Solución usando Método de Euler")
plt.legend()
plt.show()
# Out:
# [0, 0.2, 0.4388888888888889, 0.721242756361804, 1.0520380316573712, 1.4372511475238394, 1.8842608053291532, 2.402269588561542, 3.0028371645572136, 3.7006007049327985, 4.5142774281767]
# t = 1.25, Error: 0.02393
# t = 1.93, Error: 0.18780

# %%
from typing import Callable
import numpy as np
import matplotlib.pyplot as plt

def ODE_euler(
    *,
    a: float,
    b: float,
    f: Callable[[float, float], float],
    y_t0: float,
    N: int,
) -> tuple[list[float], list[float], float]:
    
    h = (b - a) / N #Se debe ajustar N para que h = 0.1
    t = a
    ts = [t]
    ys = [y_t0]

    for _ in range(N):
        y = ys[-1]
        y += h * f(t, y)
        ys.append(y)
        t += h
        ts.append(t)
    return ys, ts, h

f = lambda t, y: -(y + 1)*(y + 3)
y_t0 = -2

a = 0
b = 2

ys,ts, h = ODE_euler(a=a, b=b, y_t0=y_t0, f=f, N=10)
print(ys)


# Parámetros del problema
h=0.2
n = int((b - a) / h) + 1 #numero de pasos

def solucion_real(t):
    return -3 + 2 / (1 + np.exp(-2*t))
t_values = np.linspace(a, b, n)
y_values = np.zeros(n)

# Calculamos la solución real en los puntos t_values
sol_real = solucion_real(t_values)

#Calcular interpolación

def linear_interpolation(x0: float, y0: float, x1: float, y1: float, x: float) -> float:
    return y0 + (y1 - y0) * (x - x0) / (x1 - x0)

def interpolate_and_compare(ts, ys, exact_solution, points):
    results = []
    for t in points:
        # Encontrar los puntos entre los que se va a interpolar
        for i in range(len(ts) - 1):
            if ts[i] <= t <= ts[i+1]:
                approx = linear_interpolation(ts[i], ys[i], ts[i+1], ys[i+1], t)
                exact = exact_solution(t)
                error = abs(approx - exact)
                results.append((t, approx, exact, error))
                break
    return results
# Puntos a interpolar
points_a = [1.10, 1.75]

# Interpolación y comparación
results_a = interpolate_and_compare(ts, ys, solucion_real, points_a)

# Mostrar resultados
for t, approx, exact, error in results_a:
    print(f"t = {t:.2f}, Error: {error:.5f}")


#Graficar
for t, approx, exact, _ in results_a:
    plt.plot([t, t], [exact, approx], 'g--')  # Línea entre la solución real y la aproximación

# Mostrar los puntos exactos y aproximados
exact_ts = [t for t, _, exact, _ in results_a]
exact_ys = [exact for _, _, exact, _ in results_a]
approx_ys = [approx for _, approx, _, _ in results_a]

plt.plot(exact_ts, exact_ys, 'ro', label="Solución exacta en puntos interpolados")
plt.plot(exact_ts, approx_ys, 'bo', label="Aproximación en puntos interpolados")


plt.plot(t_values, sol_real, 'r-', label="Solución real")

plt.plot(ts, ys, marker="o", linestyle=":", label=r"$\hat{y}$")
plt.xlabel("Time")
plt.ylabel("Y")
plt.title("Solución usando Método de Euler")
plt.legend()
plt.show()
# Out:
# [-2, -1.8, -1.608, -1.4387328000000001, -1.3017369739591682, -1.199251224666308, -1.1274909449059896, -1.079745355150198, -1.0491190774237251, -1.0299539832076265, -1.0181518381465764]
# t = 1.10, Error: 0.03613
# t = 1.75, Error: 0.02388

# %% [markdown]
# ## 6. Use el método de Taylor de orden 2 para aproximar las soluciones para cada uno de los siguientes problemas de valor inicial.

# %%
# Definición de la derivada primera y segunda
def f(t, y):
    return t * np.exp(3*t) - 2*y

def f_prime(t, y):
    return np.exp(3 * t) * (3 * t + 1)  # Segunda derivada usando la ecuación diferencial

# Parámetros iniciales
h = 0.5
t0 = 0
y0 = 0
tf = 1
n_steps = int((tf - t0) / h)

# Inicialización de listas para almacenar los resultados
t_values = [t0]
y_values = [y0]

# Método de Taylor de orden 2
for i in range(n_steps):
    t_next = t_values[-1] + h
    y_next = y_values[-1] + h * f(t_values[-1], y_values[-1]) + (h**2 / 2) * f_prime(t_values[-1], y_values[-1])
    t_values.append(t_next)
    y_values.append(y_next)

t_values, y_values
# Out:
# ([0, 0.5, 1.0], [0, np.float64(0.125), np.float64(2.5209501020651612)])
